# %% [markdown]
# import pandas as pd

# %%
car_series = pd.Series(["Toyota","Honda","Lexus","BMW"])

# %%
car_series
# Out:
# 0    Toyota
# 1     Honda
# 2     Lexus
# 3       BMW
# dtype: object

# %%
colour = pd.Series(["White","Black","Green","Blue"])

# %%
colour
# Out:
# 0    White
# 1    Black
# 2    Green
# 3     Blue
# dtype: object

# %%
#using dataframe
car_data = pd.DataFrame({"Car Name": car_series, "Colour": colour})

# %%
car_data
# Out:
#   Car Name Colour
# 0   Toyota  White
# 1    Honda  Black
# 2    Lexus  Green
# 3      BMW   Blue

# %%
#Importing Data from CSV
car_sales = pd.read_csv("/content/drive/MyDrive/Pandas/car_sales.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
car_sales
# Out:
#        Name Colour  Odometer(KM)  Doors  Model       Price
# 0    Toyota  Black        150043      4   2015  $1,000,000
# 1     Lexus  White         87899      4   2021  $1,000,000
# 2     Honda    Red         32549      3   2021  $1,000,000
# 3       BMW  Black         11179      5   2021  $1,000,000
# 4  Mercedes   Blue        213095      4   2021  $1,000,000
# 5      Opal   Grey         99213      4   2021  $1,000,000
# 6      Audi  White         45698      3   2021  $1,000,000

# %%
#Exporting file as a csv file
car_sales.to_csv("Exported-car-sales.csv", index=False)

# %%
exported_car_sales = pd.read_csv("Exported-car-sales.csv")

# %%
exported_car_sales
# Out:
#        Name Colour  Model        Price
# 0    Toyota  Black   2015  $1,000,000
# 1     Lexus  White   2021  $1,000,000
# 2     Honda    Red   2021  $1,000,000
# 3       BMW  Black   2021  $1,000,000
# 4  Mercedes   Blue   2021  $1,000,000
# 5      Opal   Grey   2021  $1,000,000
# 6      Audi  White   2021  $1,000,000

# %%
#Showing the data only from the top
car_sales.head()
# Out:
#        Name Colour  Model        Price
# 0    Toyota  Black   2015  $1,000,000
# 1     Lexus  White   2021  $1,000,000
# 2     Honda    Red   2021  $1,000,000
# 3       BMW  Black   2021  $1,000,000
# 4  Mercedes   Blue   2021  $1,000,000

# %%
#Showing the data from top to 0 index to 6
car_sales.head(7)
# Out:
#        Name Colour  Model        Price
# 0    Toyota  Black   2015  $1,000,000
# 1     Lexus  White   2021  $1,000,000
# 2     Honda    Red   2021  $1,000,000
# 3       BMW  Black   2021  $1,000,000
# 4  Mercedes   Blue   2021  $1,000,000
# 5      Opal   Grey   2021  $1,000,000
# 6      Audi  White   2021  $1,000,000

# %% [markdown]
# # Describe Data

# %%
# Attribut
car_sales.dtypes
# Function
#car_sales.to_csv()#This is a function cause it contains ()
# Out:
# Name            object
# Colour          object
# Odometer(KM)     int64
# Doors            int64
# Model            int64
# Price           object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Name', 'Colour', 'Odometer(KM)', 'Doors', 'Model', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns

# %%
car_columns
# Out:
# Index(['Name', 'Colour', 'Odometer(KM)', 'Doors', 'Model', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
#Functions
car_sales.describe()#Describe Works only on integer values
# Out:
#         Odometer(KM)     Doors        Model
# count       7.000000  7.000000     7.000000
# mean    91382.285714  3.857143  2020.142857
# std     71074.484514  0.690066     2.267787
# min     11179.000000  3.000000  2015.000000
# 25%     39123.500000  3.500000  2021.000000
# 50%     87899.000000  4.000000  2021.000000
# 75%    124628.000000  4.000000  2021.000000
# max    213095.000000  5.000000  2021.000000

# %%
car_sales.info()#It is like index combined with dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          7 non-null      object
#  1   Colour        7 non-null      object
#  2   Odometer(KM)  7 non-null      int64
#  3   Doors         7 non-null      int64
#  4   Model         7 non-null      int64
#  5   Price         7 non-null      object
# dtypes: int64(3), object(3)
# memory usage: 464.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer(KM)    91382.285714
# Doors               3.857143
# Model            2020.142857
# dtype: float64

# %%
car_prices = pd.Series([3000,1500,111250])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
car_sales.sum()
# Out:
# Name                          ToyotaLexusHondaBMWMercedesOpalAudi
# Colour                            BlackWhiteRedBlackBlueGreyWhite
# Odometer(KM)                                               639676
# Doors                                                          27
# Model                                                       14141
# Price           $1,000,000$1,000,000$1,000,000$1,000,000$1,000...
# dtype: object

# %%
car_sales["Doors"].sum()#To sum specific integer type values
# Out:
# 27

# %%
len(car_sales)
# Out:
# 7

# %% [markdown]
# # Viewing & Selecting Data

# %%
# Viewing data using head function
car_sales.head()
# Out:
#        Name Colour  Odometer(KM)  Doors  Model       Price
# 0    Toyota  Black        150043      4   2015  $1,000,000
# 1     Lexus  White         87899      4   2021  $1,000,000
# 2     Honda    Red         32549      3   2021  $1,000,000
# 3       BMW  Black         11179      5   2021  $1,000,000
# 4  Mercedes   Blue        213095      4   2021  $1,000,000

# %%
# Showing till specific count data using head(Top to bottom)
car_sales.head(3)
# Out:
#      Name Colour  Odometer(KM)  Doors  Model       Price
# 0  Toyota  Black        150043      4   2015  $1,000,000
# 1   Lexus  White         87899      4   2021  $1,000,000
# 2   Honda    Red         32549      3   2021  $1,000,000

# %%
# Now Using Tail function to show data from the bottom
car_sales.tail(3)
# Out:
#        Name Colour  Odometer(KM)  Doors  Model       Price
# 4  Mercedes   Blue        213095      4   2021  $1,000,000
# 5      Opal   Grey         99213      4   2021  $1,000,000
# 6      Audi  White         45698      3   2021  $1,000,000

# %%
# Now Look at .loc & iloc
animals = pd.Series(["cat","Dog","bird", "Pandas","Snake"],
                    index=[0,3,9,8,3])# Giving index numbering by user
animals
# Out:
# 0       cat
# 3       Dog
# 9      bird
# 8    Pandas
# 3     Snake
# dtype: object

# %%
# Showing dat using index 
animals.loc[3]
# Out:
# 3      Dog
# 3    Snake
# dtype: object

# %%
car_sales.loc[3]
# Out:
# Name                   BMW
# Colour               Black
# Odometer(KM)         11179
# Doors                    5
# Model                 2021
# Price           $1,000,000
# Name: 3, dtype: object

# %%
# .iloc refers to position number
animals.iloc[3]
# Out:
# 'Pandas'

# %%
# Getting data from and upto value data using .iloc
car_sales.iloc[:3]
# Out:
#      Name Colour  Odometer(KM)  Doors  Model       Price
# 0  Toyota  Black        150043      4   2015  $1,000,000
# 1   Lexus  White         87899      4   2021  $1,000,000
# 2   Honda    Red         32549      3   2021  $1,000,000

# %%
car_sales.head(3)
# Out:
#      Name Colour  Odometer(KM)  Doors  Model       Price
# 0  Toyota  Black        150043      4   2015  $1,000,000
# 1   Lexus  White         87899      4   2021  $1,000,000
# 2   Honda    Red         32549      3   2021  $1,000,000

# %%
car_sales.loc[:3] # It shows data until index 3
# Out:
#      Name Colour  Odometer(KM)  Doors  Model       Price
# 0  Toyota  Black        150043      4   2015  $1,000,000
# 1   Lexus  White         87899      4   2021  $1,000,000
# 2   Honda    Red         32549      3   2021  $1,000,000
# 3     BMW  Black         11179      5   2021  $1,000,000

# %%
car_sales
# Out:
#        Name Colour  Odometer(KM)  Doors  Model       Price
# 0    Toyota  Black        150043      4   2015  $1,000,000
# 1     Lexus  White         87899      4   2021  $1,000,000
# 2     Honda    Red         32549      3   2021  $1,000,000
# 3       BMW  Black         11179      5   2021  $1,000,000
# 4  Mercedes   Blue        213095      4   2021  $1,000,000
# 5      Opal   Grey         99213      4   2021  $1,000,000
# 6      Audi  White         45698      3   2021  $1,000,000

# %%
# Viewing the data of specific column
# The data of the column name containing spaces can also be seen using string
car_sales["Model"]
# Out:
# 0    2015
# 1    2021
# 2    2021
# 3    2021
# 4    2021
# 5    2021
# 6    2021
# Name: Model, dtype: int64

# %%
# Viewing data iside the file greater than the value required value
car_sales[car_sales["Model"]>2015]
# Out:
#        Name Colour  Odometer(KM)  Doors  Model       Price
# 1     Lexus  White         87899      4   2021  $1,000,000
# 2     Honda    Red         32549      3   2021  $1,000,000
# 3       BMW  Black         11179      5   2021  $1,000,000
# 4  Mercedes   Blue        213095      4   2021  $1,000,000
# 5      Opal   Grey         99213      4   2021  $1,000,000
# 6      Audi  White         45698      3   2021  $1,000,000

# %%
# Viewing the data from file from specific column and specific value of the column
car_sales[car_sales["Colour"]=="Black"]
# Out:
#      Name Colour  Odometer(KM)  Doors  Model       Price
# 0  Toyota  Black        150043      4   2015  $1,000,000
# 3     BMW  Black         11179      5   2021  $1,000,000

# %%
# To view data using .
car_sales.Model # If the column name contains space then it can't be used
# Out:
# 0    2015
# 1    2021
# 2    2021
# 3    2021
# 4    2021
# 5    2021
# 6    2021
# Name: Model, dtype: int64

# %%
car_columns.Model
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-f95f7b5348bd> in <module>()
# ----> 1 car_columns.Model
#
# AttributeError: 'Index' object has no attribute 'Model'

# %%
# It tells only the number and index of the columns present in the data in the file
car_columns
# Out:
# Index(['Name', 'Colour', 'Odometer(KM)', 'Doors', 'Model', 'Price'], dtype='object')

# %%
car_sales.dtypes
# Out:
# Name            object
# Colour          object
# Odometer(KM)     int64
# Doors            int64
# Model            int64
# Price           object
# dtype: object
