# %%
#Importing pandas library
import pandas as pd

# %% [markdown]
# # Data Types in Pandas

# %%
# Using Series Datatype of Pandas
animal_names = pd.Series(["Dog","Cat","Donkey","Horse","Monkey","Lion"])
# Now calling Series
animal_names
# Out:
# 0       Dog
# 1       Cat
# 2    Donkey
# 3     Horse
# 4    Monkey
# 5      Lion
# dtype: object

# %%
# Making another series
animal_sound = pd.Series(["Baoo Baoo","Meow","Ay au","Ehehehe","Ay ay","Roar"])
animal_sound
# Out:
# 0    Baoo Baoo
# 1         Meow
# 2        Ay au
# 3      Ehehehe
# 4        Ay ay
# 5         Roar
# dtype: object

# %%
# Now make a DataFrame another type of Pandas
animal_data = pd.DataFrame({"Animal Name":animal_names, "Animal Sound":animal_sound})
# Now Calling DataFrame combined with Series
animal_data
# Out:
#   Animal Name Animal Sound
# 0         Dog    Baoo Baoo
# 1         Cat         Meow
# 2      Donkey        Ay au
# 3       Horse      Ehehehe
# 4      Monkey        Ay ay
# 5        Lion         Roar

# %% [markdown]
# # Imorting & Exporting files

# %%
# Importing data from the file
Animal_sales = pd.read_csv("/content/drive/MyDrive/Pandas/animal_sales.csv")

# %%
Animal_sales
# Out:
#   Animal Name  Animal Quantity  Legs     Price
# 0       Horse                5     4   $10,000
# 1         Cat               10     4    $1,000
# 2         Dog                2     4      $100
# 3        Lion                1     4  $100,000
# 4      Monkey                2     2    $1,500
# 5       Tiger                3     4  $150,000
# 6       Snake                1     0   $20,000

# %%
# Exporting file
export_animal_sales = Animal_sales.to_csv("Exported_animal_sales.csv",index=False)
export_animal_sales

# %%
exported_animal_sales = pd.read_csv("Exported_animal_sales.csv")
exported_animal_sales
# Out:
#   Animal Name  Animal Quantity  Legs     Price
# 0       Horse                5     4   $10,000
# 1         Cat               10     4    $1,000
# 2         Dog                2     4      $100
# 3        Lion                1     4  $100,000
# 4      Monkey                2     2    $1,500
# 5       Tiger                3     4  $150,000
# 6       Snake                1     0   $20,000

# %% [markdown]
# # Describe Data

# %%
animal_data.dtypes
# Out:
# Animal Name     object
# Animal Sound    object
# dtype: object

# %%
# Looking at the data type of the data in the file
Animal_sales.dtypes
# Out:
# Animal Name        object
# Animal Quantity     int64
# Legs                int64
# Price              object
# dtype: object

# %%
# Now using columns Attribute to see columns inside the file
Animal_sales.columns
# Out:
# Index(['Animal Name', 'Animal Quantity', 'Legs', 'Price'], dtype='object')

# %%
# Now using index Attribute to see the indexes inside the file
Animal_sales.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
# Saving it in another variable to easily accessible for future use
animal_columns = Animal_sales.columns
animal_columns
# Out:
# Index(['Animal Name', 'Animal Quantity', 'Legs', 'Price'], dtype='object')

# %%
# Now using Functions
# Describe Function
Animal_sales.describe()
# Out:
#        Animal Quantity      Legs
# count         7.000000  7.000000
# mean          3.428571  3.142857
# std           3.207135  1.573592
# min           1.000000  0.000000
# 25%           1.500000  3.000000
# 50%           2.000000  4.000000
# 75%           4.000000  4.000000
# max          10.000000  4.000000

# %%
# Now using info Funciton(it combines index with dtypes)
Animal_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Animal Name      7 non-null      object
#  1   Animal Quantity  7 non-null      int64
#  2   Legs             7 non-null      int64
#  3   Price            7 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 352.0+ bytes

# %%
# Now using len funciton to see the length of the data in the file
len(Animal_sales)
# Out:
# 7

# %%
# To find the mean of the data
Animal_sales.mean()
# Out:
# Animal Quantity    3.428571
# Legs               3.142857
# dtype: float64

# %%
# To sum the data in the file according to each column head
Animal_sales.sum()
# Out:
# Animal Name                       HorseCatDogLionMonkeyTigerSnake
# Animal Quantity                                                24
# Legs                                                           22
# Price              $10,000$1,000$100$100,000$1,500$150,000$20,000
# dtype: object

# %%
# To find the sum of specific data column in the file
Animal_sales["Legs"].sum()
# Out:
# 22

# %%
Animal_sales
# Out:
#   Animal Name  Animal Quantity  Legs     Price
# 0       Horse                5     4   $10,000
# 1         Cat               10     4    $1,000
# 2         Dog                2     4      $100
# 3        Lion                1     4  $100,000
# 4      Monkey                2     2    $1,500
# 5       Tiger                3     4  $150,000
# 6       Snake                1     0   $20,000

# %% [markdown]
# # Viewing & Selecting Data

# %%
# viewing the data by slection
Animal_sales[Animal_sales["Legs"]>2]
# Out:
#   Animal Name  Animal Quantity  Legs     Price
# 0       Horse                5     4   $10,000
# 1         Cat               10     4    $1,000
# 2         Dog                2     4      $100
# 3        Lion                1     4  $100,000
# 5       Tiger                3     4  $150,000

# %%
# Viewing the Data types of the data in the file
Animal_sales.dtypes
# Out:
# Animal Name        object
# Animal Quantity     int64
# Legs                int64
# Price              object
# dtype: object

# %%
# Viewing the data by Selection
Animal_sales[Animal_sales["Animal Quantity"]>2]
# Out:
#   Animal Name  Animal Quantity  Legs     Price
# 0       Horse                5     4   $10,000
# 1         Cat               10     4    $1,000
# 5       Tiger                3     4  $150,000

# %%
# Viewing the data by Selection and Logical Operator
Animal_sales[Animal_sales["Animal Name"]!=]
# Out:
#   Animal Name  Animal Quantity  Legs     Price
# 0       Horse                5     4   $10,000
# 2         Dog                2     4      $100
# 3        Lion                1     4  $100,000
# 4      Monkey                2     2    $1,500
# 5       Tiger                3     4  $150,000
# 6       Snake                1     0   $20,000

# %%
# Showing the data using head Function
Animal_sales.head()
# Out:
#   Animal Name  Animal Quantity  Legs     Price
# 0       Horse                5     4   $10,000
# 1         Cat               10     4    $1,000
# 2         Dog                2     4      $100
# 3        Lion                1     4  $100,000
# 4      Monkey                2     2    $1,500

# %%
# Showing the data with til specific lines from top using head
Animal_sales.head(3)
# Out:
#   Animal Name  Animal Quantity  Legs    Price
# 0       Horse                5     4  $10,000
# 1         Cat               10     4   $1,000
# 2         Dog                2     4     $100

# %%
# Showing the data from botoom to top using tail
Animal_sales.tail()
# Out:
#   Animal Name  Animal Quantity  Legs     Price
# 2         Dog                2     4      $100
# 3        Lion                1     4  $100,000
# 4      Monkey                2     2    $1,500
# 5       Tiger                3     4  $150,000
# 6       Snake                1     0   $20,000

# %%
# Showing the data from botoom to top using tail till specific lines
Animal_sales.tail(4)
# Out:
#   Animal Name  Animal Quantity  Legs     Price
# 3        Lion                1     4  $100,000
# 4      Monkey                2     2    $1,500
# 5       Tiger                3     4  $150,000
# 6       Snake                1     0   $20,000

# %%
# Showing the data using .loc & .iloc
car_name = pd.Series(["Toyota","BMW","Suzuki","Opal"],
                     index = [0,2,5])
car_name
# Out:
# 0    Toyota
# 1       BMW
# 2    Suzuki
# 3      Opal
# dtype: object

# %%
Animal_sales
# Out:
#   Animal Name  Animal Quantity  Legs     Price
# 0       Horse                5     4   $10,000
# 1         Cat               10     4    $1,000
# 2         Dog                2     4      $100
# 3        Lion                1     4  $100,000
# 4      Monkey                2     2    $1,500
# 5       Tiger                3     4  $150,000
# 6       Snake                1     0   $20,000

# %%
# Now trying to view the data type of single attribute or column
Animal_sales["Price"].dtype
# Out:
# dtype('O')

# %%
# Now showing the data comparing two columns
pd.crosstab(Animal_sales["Animal Name"], Animal_sales["Animal Quantity"])
# Out:
# Animal Quantity  1   2   3   5   10
# Animal Name
# Cat               0   0   0   0   1
# Dog               0   1   0   0   0
# Horse             0   0   0   1   0
# Lion              1   0   0   0   0
# Monkey            0   1   0   0   0
# Snake             1   0   0   0   0
# Tiger             0   0   1   0   0

# %%
# Using Groupby
Animal_sales.groupby(Animal_sales["Animal Name"]).mean()
# Out:
#              Animal Quantity  Legs
# Animal Name
# Cat                       10     4
# Dog                        2     4
# Horse                      5     4
# Lion                       1     4
# Monkey                     2     2
# Snake                      1     0
# Tiger                      3     4

# %%
# Importing data of car_sales
car_sales = pd.read_csv("/content/drive/MyDrive/Pandas/car_sales.csv")

# %%
car_sales
# Out:
#        Name Colour  Odometer(KM)  Doors  Model       Price
# 0    Toyota  Black        150043      4   2015  $1,000,000
# 1     Lexus  White         87899      4   2021  $1,000,000
# 2     Honda    Red         32549      3   2021  $1,000,000
# 3       BMW  Black         11179      5   2021  $1,000,000
# 4  Mercedes   Blue        213095      4   2021  $1,000,000
# 5      Opal   Grey         99213      4   2021  $1,000,000
# 6      Audi  White         45698      3   2021  $1,000,000

# %%
pd.crosstab(car_sales["Name"], car_sales["Doors"])
# Out:
# Doors     3  4  5
# Name
# Audi      1  0  0
# BMW       0  0  1
# Honda     1  0  0
# Lexus     0  1  0
# Mercedes  0  1  0
# Opal      0  1  0
# Toyota    0  1  0

# %%
# If it doesn't plot the graph then import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

car_sales["Odometer(KM)"].plot()

# %%
car_sales["Odometer(KM)"].hist()

# %%
# Converting Price column to integer value
car_sales["Price"] = car_sales["Price"].str.replace('[/,\$.]','').astype(int)

# %%
car_sales
# Out:
#        Name Colour  Odometer(KM)  Doors  Model    Price
# 0    Toyota  Black        150043      4   2015  1000000
# 1     Lexus  White         87899      4   2021  1000000
# 2     Honda    Red         32549      3   2021  1000000
# 3       BMW  Black         11179      5   2021  1000000
# 4  Mercedes   Blue        213095      4   2021  1000000
# 5      Opal   Grey         99213      4   2021  1000000
# 6      Audi  White         45698      3   2021  1000000

# %%
car_sales["Price"].plot()

# %%
car_sales.mean()
# Out:
# Odometer(KM)      91382.285714
# Doors                 3.857143
# Model              2020.142857
# Price           1000000.000000
# dtype: float64

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          7 non-null      object
#  1   Colour        7 non-null      object
#  2   Odometer(KM)  7 non-null      int64
#  3   Doors         7 non-null      int64
#  4   Model         7 non-null      int64
#  5   Price         7 non-null      int64
# dtypes: int64(4), object(2)
# memory usage: 464.0+ bytes

# %%
car_sales.describe()
# Out:
#         Odometer(KM)     Doors        Model      Price
# count       7.000000  7.000000     7.000000        7.0
# mean    91382.285714  3.857143  2020.142857  1000000.0
# std     71074.484514  0.690066     2.267787        0.0
# min     11179.000000  3.000000  2015.000000  1000000.0
# 25%     39123.500000  3.500000  2021.000000  1000000.0
# 50%     87899.000000  4.000000  2021.000000  1000000.0
# 75%    124628.000000  4.000000  2021.000000  1000000.0
# max    213095.000000  5.000000  2021.000000  1000000.0

# %% [markdown]
# # Manipulating Data

# %%
# Showing the Names in lower letters from the file
car_sales["Name"].str.lower()
# Out:
# 0      toyota
# 1       lexus
# 2       honda
# 3         bmw
# 4    mercedes
# 5        opal
# 6        audi
# Name: Name, dtype: object

# %%
car_sales
# Out:
#        Name Colour  Odometer(KM)  Doors  Model    Price
# 0    Toyota  Black        150043      4   2015  1000000
# 1     Lexus  White         87899      4   2021  1000000
# 2     Honda    Red         32549      3   2021  1000000
# 3       BMW  Black         11179      5   2021  1000000
# 4  Mercedes   Blue        213095      4   2021  1000000
# 5      Opal   Grey         99213      4   2021  1000000
# 6      Audi  White         45698      3   2021  1000000

# %%
# Changing the Names from Capital to lower characters
car_sales["Name"] = car_sales["Name"].str.lower()

# %%
car_sales
# Out:
#        Name Colour  Odometer(KM)  Doors  Model    Price
# 0    toyota  Black        150043      4   2015  1000000
# 1     lexus  White         87899      4   2021  1000000
# 2     honda    Red         32549      3   2021  1000000
# 3       bmw  Black         11179      5   2021  1000000
# 4  mercedes   Blue        213095      4   2021  1000000
# 5      opal   Grey         99213      4   2021  1000000
# 6      audi  White         45698      3   2021  1000000

# %%
# Importing data from car-sales-missing-data.csv file
car_sales_missing = pd.read_csv("/content/drive/MyDrive/Pandas/car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# Deleting the unsigned value in the data file using inplace to write in the datafram
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# Filling missing data NA with the mean value of the column Odometer
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean() ,inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
  car_sales_missing_drop = car_sales_missing.dropna()

# %%
car_sales_missing_drop
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
# Exporting the file after deleting the NA values form the data file
car_sales_missing_drop.to_csv("Dropped-NA-from-column", index = False)

# %%
# Importing the data file after exporting
car_sales_missing_dropped = pd.read_csv("Dropped-NA-from-column")

# %%
car_sales_missing_dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
